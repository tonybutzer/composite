# %%
! ls *.csv
# Out:
# cloud_zealots.csv

# %%
! sed '/^[[:space:]]*$/d' < cloud_zealots.csv >cloud_zealots1.csv

# %%
! cat cloud_zealots1.csv
# Out:
# Amador, Jacob D
# Anthony, Michelle (Contractor) L
# Arab, Saeed
# Austin, Clay (Contractor) G
# Ballu, Anudeep (Contractor)
# Barnes, Christopher (Contractor)
# Benedict, Trenton D
# Beverly, Sean D
# Beynon, Donelle C
# Bhattarai, Krishna (Contractor) P
# Boiko, Olena
# Bouchard, Michelle (Contractor)
# Bourget, Paul (Contractor) F
# Braa, Pamela (Contractor) MOrganizer
# Briden, Jeffrey (Contractor) A
# Bunde, Brett (Contractor)
# Butzer, Tony (Contractor)
# Callahan, Karin (Contractor) E
# Case, Adam (Contractor)
# Casey, Jacob (Contractor) G
# Chow Lin, Wai Hang
# Christianson, Austin T
# Connot, Joel (Contractor)
# Connot, Peggy (Contractor) L
# Dahal, Devendra (Contractor)
# Danielson, Patrick (Contractor)
# Davis, Brian (Contractor) N
# Degaga, Erica J
# Deis, Julia (Contractor) A
# Dittmeier, Ray (Contractor)
# Dockter, Daryn (Contractor) J
# Dornbierer, Jordan (Contractor) M
# Doucette, Peter J
# Drake, Jason D
# Fleck, Luke R
# Friedrichs, MacKenzie (Contractor) O
# ...

# %%
import pandas as pd
df = pd.read_csv('cloud_zealots1.csv', names=["lastname","firstname"])

# %%
df.head()
# Out:
#   lastname                 firstname
# 0   Amador                   Jacob D
# 1  Anthony   Michelle (Contractor) L
# 2     Arab                     Saeed
# 3   Austin       Clay (Contractor) G
# 4    Ballu      Anudeep (Contractor)

# %%
df['zealot_score'] = 'null'

# %%
df
# Out:
#      lastname                 firstname zealot_score
# 0      Amador                   Jacob D         null
# 1     Anthony   Michelle (Contractor) L         null
# 2        Arab                     Saeed         null
# 3      Austin       Clay (Contractor) G         null
# 4       Ballu      Anudeep (Contractor)         null
# ..        ...                       ...          ...
# 109    Wilson                   Holly J         null
# 110  Worstell      Bruce (Contractor) B         null
# 111     Young      Claudia (Contractor)         null
# 112   Zelenak     Daniel (Contractor) J         null
# 113    morton   Jonathan (Contractor) R         null
#
# [114 rows x 3 columns]

# %%
df['engagement_level'] = 'null'

# %%
df
# Out:
#      lastname                 firstname zealot_score engagement_level
# 0      Amador                   Jacob D         null             null
# 1     Anthony   Michelle (Contractor) L         null             null
# 2        Arab                     Saeed         null             null
# 3      Austin       Clay (Contractor) G         null             null
# 4       Ballu      Anudeep (Contractor)         null             null
# ..        ...                       ...          ...              ...
# 109    Wilson                   Holly J         null             null
# 110  Worstell      Bruce (Contractor) B         null             null
# 111     Young      Claudia (Contractor)         null             null
# 112   Zelenak     Daniel (Contractor) J         null             null
# 113    morton   Jonathan (Contractor) R         null             null
#
# [114 rows x 4 columns]

# %%
df.to_csv('zealot_wip.csv')

# %%
! ls; cat zealot_wip.csv
# Out:
# 00-geojson-viewer-panel.ipynb
# 00-sentinel-klm-study.ipynb
# 10-display-thumbnails-jpg-maine-with-sentinel.ipynb
# 10-less-clouds-display-thumbnails-jpg-maine-with-sentinel.ipynb
# 11-display-thumbnails-jpg-mexico-with-sentinel.ipynb
# 20-sat-search-explore.ipynb
# 21-sentinel-rgb-fun-and-clipping.ipynb
# 99-yaml-example.ipynb
# AOI
# Untitled.ipynb
# Untitled1.ipynb
# class_week10.yml
# cloud_zealots.csv
# cloud_zealots1.csv
# gz_2010_us_040_00_500k.json
# my-s2-l2a-cogs.json
# zealot_wip.csv
# ,lastname,firstname,zealot_score,engagement_level
# 0,Amador, Jacob D,null,null
# 1,Anthony, Michelle (Contractor) L,null,null
# 2,Arab, Saeed,null,null
# 3,Austin, Clay (Contractor) G,null,null
# 4,Ballu, Anudeep (Contractor),null,null
# 5,Barnes, Christopher (Contractor),null,null
# 6,Benedict, Trenton D,null,null
# 7,Beverly, Sean D,null,null
# 8,Beynon, Donelle C,null,null
# 9,Bhattarai, Krishna (Contractor) P,null,null
# 10,Boiko, Olena,null,null
# ...

# %%
help (df.to_csv)
# Out:
# Help on method to_csv in module pandas.core.generic:
#
# to_csv(path_or_buf: 'Optional[FilePathOrBuffer]' = None, sep: 'str' = ',', na_rep: 'str' = '', float_format: 'Optional[str]' = None, columns: 'Optional[Sequence[Label]]' = None, header: 'Union[bool_t, List[str]]' = True, index: 'bool_t' = True, index_label: 'Optional[IndexLabel]' = None, mode: 'str' = 'w', encoding: 'Optional[str]' = None, compression: 'CompressionOptions' = 'infer', quoting: 'Optional[int]' = None, quotechar: 'str' = '"', line_terminator: 'Optional[str]' = None, chunksize: 'Optional[int]' = None, date_format: 'Optional[str]' = None, doublequote: 'bool_t' = True, escapechar: 'Optional[str]' = None, decimal: 'str' = '.', errors: 'str' = 'strict', storage_options: 'StorageOptions' = None) -> 'Optional[str]' method of pandas.core.frame.DataFrame instance
#     Write object to a comma-separated values (csv) file.
#
#     .. versionchanged:: 0.24.0
#         The order of arguments for Series was changed.
#
# ...
