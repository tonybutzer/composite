# %%
! pip list |grep pyan3
# Out:
# pyan3                         1.0.4

# %%
! ~/.local/bin/pyan3 bit_v4_1600.py -Tdot
# Out:
# /bin/bash: /home/jovyan/.local/bin/pyan3: /usr/bin/python3: bad interpreter: No such file or directory

# %%
! python /home/jovyan/.local/bin/pyan3 bit_v4_1600.py --dot
# Out:
# digraph G {
#     graph [rankdir=TB];
#     subgraph cluster_G {
#
#         graph [style="filled,rounded",fillcolor="#80808018", label=""];
#         bit_v4_1600 [label="bit_v4_1600", style="filled", fillcolor="#ffffffb2", fontcolor="#000000", group="0"];
#         bit_v4_1600__BandMap [label="BandMap", style="filled", fillcolor="#ffffffb2", fontcolor="#000000", group="0"];
#         bit_v4_1600__DataStack [label="DataStack", style="filled", fillcolor="#ffffffb2", fontcolor="#000000", group="0"];
#         bit_v4_1600__QAMap [label="QAMap", style="filled", fillcolor="#ffffffb2", fontcolor="#000000", group="0"];
#         bit_v4_1600__align [label="align", style="filled", fillcolor="#ffffffb2", fontcolor="#000000", group="0"];
#         bit_v4_1600__buildaffine [label="buildaffine", style="filled", fillcolor="#ffffffb2", fontcolor="#000000", group="0"];
# ...

# %%
! python /home/jovyan/.local/bin/pyan3 -c bit_v4_1600.py --dot | dot -Tpng -o bit.png

# %%
from IPython.display import Image
Image(filename='bit.png')

# %%
! pip list | grep grap
# Out:
# cryptography                  3.4.4

# %%
conda list | grep graph
# Out:
# cryptography              3.4.4            py37hf1a17b8_0    conda-forge
# graphite2                 1.3.13            h58526e2_1001    conda-forge
# graphviz                  2.46.1               h93c640b_4    conda-forge
#
# Note: you may need to restart the kernel to use updated packages.

# %%
! python /home/jovyan/.local/bin/pyan3 --help
# Out:
# Usage: pyan3 FILENAME... [--dot|--tgf|--yed]
#
# Analyse one or more Python source files and generate anapproximate call graph
# of the modules, classes and functions within them.
#
# Options:
#   -h, --help            show this help message and exit
#   --dot                 output in GraphViz dot format
#   --tgf                 output in Trivial Graph Format
#   --yed                 output in yEd GraphML Format
#   -f FILE, --file=FILE  write graph to FILE
#   -l LOG, --log=LOG     write log to LOG
#   -v, --verbose         verbose output
#   -V, --very-verbose    even more verbose output (mainly for debug)
#   -d, --defines         add edges for 'defines' relationships [default]
#   -n, --no-defines      do not add edges for 'defines' relationships
#   -u, --uses            add edges for 'uses' relationships [default]
#   -N, --no-uses         do not add edges for 'uses' relationships
#   -c, --colored         color nodes according to namespace [dot only]
# ...
